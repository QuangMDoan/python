# %%
import random as rd

def simulate_dice_rolls(N):
    roll_counts = [0, 0, 0, 0, 0, 0]
    for i in range(N):
        roll = rd.choice([1,2,3,4,5,6])
        index = roll - 1
        roll_counts[index] += 1
    return roll_counts

def show_rolls_data(roll_counts):
    for dice_side, frequency in enumerate(roll_counts):
        print(f"{dice_side + 1} was rolled {frequency} times")

roll_data = simulate_dice_rolls(1000)
show_rolls_data(roll_data)
# Out:
# 1 was rolled 184 times
# 2 was rolled 157 times
# 3 was rolled 156 times
# 4 was rolled 171 times
# 5 was rolled 157 times
# 6 was rolled 175 times

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

def visualize_one_die(roll_data):
    roll_outcomes = [1,2,3,4,5,6]
    fig, ax = plt.subplots()
    ax.bar(roll_outcomes, roll_data)
    ax.set_xlabel("Value on Die")
    ax.set_title("Simulated Counts of Rolls")
    plt.show()

roll_data = simulate_dice_rolls(500)
visualize_one_die(roll_data)
